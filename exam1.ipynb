# %%
import numpy as np
from scipy import stats as st

# %%
list1 = [16, 14, 11, 14, 11, 13, 20, 11, 10, 8, 4, 3, 14, 14, 8]

# %%
np.mean(list1)
# Out:
# 11.4

# %%
np.median(list1)
# Out:
# 11.0

# %%
print(st.mode(list1))
# Out:
# ModeResult(mode=14, count=4)

# %%
array1 = np.array(list1)

# Calculate the range
range_value = np.ptp(array1)
range_value
# Out:
# 17

# %%
np.var(list1)
# Out:
# 18.37333333333333

# %%
np.std(list1)
# Out:
# 4.286412641514269
